# %% [markdown]
# # Library importing

# %%
import pandas as pd
import json

# %% [markdown]
# ## Operation using pandas

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# ## HTML File fetching

# %%
df = pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")

# %%
l = pd.read_html('https://stats.espncricinfo.com/ci/engine/records/averages/batting.html?class=3;id=6;type=team')

# %%
l[0]
# Out:
#                Player       Span  Mat Inns NO  Runs   HS    Ave   BF      SR  \
# 0          AB Agarkar  2006-2007    4    2  0    15   14   7.50   11  136.36
# 1            KK Ahmed  2018-2019   14    1  1     1   1*      -    1  100.00
# 2           S Aravind  2015-2015    1    -  -     -    -      -    -       -
# 3            R Ashwin  2010-2021   51   11  7   123  31*  30.75  115  106.95
# 4          Avesh Khan  2022-2022    2    -  -     -    -      -    -       -
# ..                ...        ...  ...  ... ..   ...  ...    ...  ...     ...
# 92      R Vinay Kumar  2010-2013    9    1  1     2   2*      -    4   50.00
# 93  Washington Sundar  2017-2021   31   11  4    47  14*   6.71   32  146.87
# 94           SA Yadav  2021-2022   14   12  3   351   65  39.00  212  165.56
# 95           UT Yadav  2012-2019    7    1  0     2    2   2.00    4   50.00
# 96       Yuvraj Singh  2007-2017   58   51  9  1177  77*  28.02  863  136.38
#
#    100 50  0  4s  6s
# 0    0  0  0   2   0
# 1    0  0  0   0   0
# 2    -  -  -   -   -
# 3    0  0  0  14   1
# 4    -  -  -   -   -
# ..  .. .. ..  ..  ..
# 92   0  0  0   0   0
# 93   0  0  3   4   3
# 94   0  4  1  32  20
# 95   0  0  0   0   0
# 96   0  8  1  77  74
#
# [97 rows x 15 columns]

# %%
d ="""{"name" : "Sudhanshu kumar" , 
"email id " : "sskumar@gmail.com",
"tech" : ["ML" , "DL" , "CV" ],
"plateform" : ["techneuron" , "kidsneuron" , "ineuron"]
}"""

# %%
result  = json.loads(d)

# %%
pd.DataFrame(result)
# Out:
#               name          email id  tech   plateform
# 0  Sudhanshu kumar  sskumar@gmail.com   ML  techneuron
# 1  Sudhanshu kumar  sskumar@gmail.com   DL  kidsneuron
# 2  Sudhanshu kumar  sskumar@gmail.com   CV     ineuron

# %% [markdown]
# ## Battery data

# %%
d = {"packetType":"D","data":{"checkEngineLightFlag":"F","batteryVoltageStableTime":0,"batteryVoltageStable":"0","batteryVoltageOff":"12.42","batteryCrankParamTN":"-0.08","batteryCrankParamVN":"0.00","batteryCrankParamTP":"-0.08","batteryCrankParamVP":"0.00","batteryCrankParamTT":"-0.00008","batteryCrankParamV0":"0.00","batteryVoltageMaxOn":"13.05","batteryVoltageMinOn":"12.97","batteryVoltageMaxOff":"12.46","batteryVoltageMinOff":"12.36","batteryVoltageOnAverage":"13.02","engineLoadMax":"84","engineLoadAverage":"39.98","rpmMax":"3487","rpmAverage":"1431.29","gpsSpeedAverage":"21.99","vssMax":"53.44","vssAverage":"23.06","tcuTemperatureMin":"82.40","tcuTemperatureMax":"109.40","tcuTemperatureAverage":"104.87","coolantMin":"158.00","coolantMax":"188.60","coolantAverage":"180.20","packetStartLocal":1508143346000,"tripStartLocal":1508143346000,"milIndicator":"F","monitorsNotReady":0,"imei":"60DF5417","gatewayTs":1515613306592,"diagnosticTroubleCodeData":[],"diagnosticPidData":[[64768,47,100],[64768,1,517376],[64800,1,262144],[64768,5,125]]},"header":{"iwrapVer":"1.9.20","sourceSystem":"CDP","configVer":"1.1","oemName":"HUM","unitType":0,"cpVer":"7.50.1.9","igpsVer":"1.3.7","messageType":"Notification","pomVer":"1.0","headerVer":"V6","timestamp":0,"deviceType":"InDrive","visorVer":"1.4.35","transactionId":"53098471-7787-4160-94b3-cd69dcc70416","deviceSerialNo":"60DF5417","subOrganization":"HUM","organization":"HUM","imei":"60DF5417","operation":"Notification"}}

# %%
only_data = d['data']

# %%
# only_data.pop('diagnosticTroubleCodeData')
pd.DataFrame(only_data)
# Out:
#   checkEngineLightFlag  batteryVoltageStableTime batteryVoltageStable  \
# 0                    F                         0                    0
# 1                    F                         0                    0
# 2                    F                         0                    0
# 3                    F                         0                    0
#
#   batteryVoltageOff batteryCrankParamTN batteryCrankParamVN  \
# 0             12.42               -0.08                0.00
# 1             12.42               -0.08                0.00
# 2             12.42               -0.08                0.00
# 3             12.42               -0.08                0.00
#
#   batteryCrankParamTP batteryCrankParamVP batteryCrankParamTT  \
# 0               -0.08                0.00            -0.00008
# 1               -0.08                0.00            -0.00008
# 2               -0.08                0.00            -0.00008
# 3               -0.08                0.00            -0.00008
#
#   batteryCrankParamV0  ... coolantMin coolantMax coolantAverage  \
# 0                0.00  ...     158.00     188.60         180.20
# 1                0.00  ...     158.00     188.60         180.20
# 2                0.00  ...     158.00     188.60         180.20
# 3                0.00  ...     158.00     188.60         180.20
#
#   packetStartLocal tripStartLocal milIndicator monitorsNotReady      imei  \
# 0    1508143346000  1508143346000            F                0  60DF5417
# 1    1508143346000  1508143346000            F                0  60DF5417
# 2    1508143346000  1508143346000            F                0  60DF5417
# 3    1508143346000  1508143346000            F                0  60DF5417
#
#        gatewayTs   diagnosticPidData
# 0  1515613306592    [64768, 47, 100]
# 1  1515613306592  [64768, 1, 517376]
# 2  1515613306592  [64800, 1, 262144]
# 3  1515613306592     [64768, 5, 125]
#
# [4 rows x 35 columns]

# %% [markdown]
# ## Git-hub remote data

# %%
import requests
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
arr = requests.get(url)
result = arr.json()

# %%
result[0]['user']
# Out:
# {'login': 'jbrockmendel',
#  'id': 8078968,
#  'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/jbrockmendel',
#  'html_url': 'https://github.com/jbrockmendel',
#  'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#  'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#  'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#  'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#  'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#  'type': 'User',
#  'site_admin': False}

# %%
df_full = pd.DataFrame(result)
data_user = df_full['user']

# %%
actual_data = pd.DataFrame(data_user.to_dict()).T

# %%
df_without_user = df_full.drop(['user'],axis = 1)
df_without_user.head(3)
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
# 2  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
#
#                                           events_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
#
#                                           html_url          id  \
# 0  https://github.com/pandas-dev/pandas/pull/46236  1160198674
# 1  https://github.com/pandas-dev/pandas/pull/46234  1160089928
# 2  https://github.com/pandas-dev/pandas/pull/46232  1160064471
#
#                node_id  number  \
# 0  PR_kwDOAA0YD84z-8mt   46236
# 1  PR_kwDOAA0YD84z-mBc   46234
# 2  PR_kwDOAA0YD84z-gzl   46232
#
#                                                title  ...  \
# 0                           troubleshoot 32bit build  ...
# 1  REF: use standard pattern in _tz_convert_from_utc  ...
# 2  Adding overwrite or ignore behavior for row co...  ...
#
#              updated_at closed_at  author_association active_lock_reason  \
# 0  2022-03-05T02:51:25Z      None              MEMBER               None
# 1  2022-03-05T01:06:08Z      None              MEMBER               None
# 2  2022-03-04T21:26:16Z      None                NONE               None
#
#    draft                                       pull_request  \
# 0  False  {'url': 'https://api.github.com/repos/pandas-d...
# 1  False  {'url': 'https://api.github.com/repos/pandas-d...
# 2  False  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                                 body  \
# 0  - [ ] closes #xxxx (Replace xxxx with the Gith...
# 1  - [ ] closes #xxxx (Replace xxxx with the Gith...
# 2  @cvonsteg started the effort to implement this...
#
#                                            reactions  \
# 0  {'url': 'https://api.github.com/repos/pandas-d...
# 1  {'url': 'https://api.github.com/repos/pandas-d...
# 2  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                         timeline_url performed_via_github_app
# 0  https://api.github.com/repos/pandas-dev/pandas...                     None
# 1  https://api.github.com/repos/pandas-dev/pandas...                     None
# 2  https://api.github.com/repos/pandas-dev/pandas...                     None
#
# [3 rows x 28 columns]

# %%
df_without_user.columns
# Out:
# Index(['url', 'repository_url', 'labels_url', 'comments_url', 'events_url',
#        'html_url', 'id', 'node_id', 'number', 'title', 'labels', 'state',
#        'locked', 'assignee', 'assignees', 'milestone', 'comments',
#        'created_at', 'updated_at', 'closed_at', 'author_association',
#        'active_lock_reason', 'draft', 'pull_request', 'body', 'reactions',
#        'timeline_url', 'performed_via_github_app'],
#       dtype='object')

# %%
actual_data.head()
# Out:
#           login        id               node_id  \
# 0  jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 1  jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 2      LSturtew  56136443  MDQ6VXNlcjU2MTM2NDQz
# 3       ehallam  20362314  MDQ6VXNlcjIwMzYyMzE0
# 4        ianliu     30196      MDQ6VXNlcjMwMTk2
#
#                                           avatar_url gravatar_id  \
# 0  https://avatars.githubusercontent.com/u/807896...
# 1  https://avatars.githubusercontent.com/u/807896...
# 2  https://avatars.githubusercontent.com/u/561364...
# 3  https://avatars.githubusercontent.com/u/203623...
# 4  https://avatars.githubusercontent.com/u/30196?v=4
#
#                                          url                         html_url  \
# 0  https://api.github.com/users/jbrockmendel  https://github.com/jbrockmendel
# 1  https://api.github.com/users/jbrockmendel  https://github.com/jbrockmendel
# 2      https://api.github.com/users/LSturtew      https://github.com/LSturtew
# 3       https://api.github.com/users/ehallam       https://github.com/ehallam
# 4        https://api.github.com/users/ianliu        https://github.com/ianliu
#
#                                        followers_url  \
# 0  https://api.github.com/users/jbrockmendel/foll...
# 1  https://api.github.com/users/jbrockmendel/foll...
# 2    https://api.github.com/users/LSturtew/followers
# 3     https://api.github.com/users/ehallam/followers
# 4      https://api.github.com/users/ianliu/followers
#
#                                        following_url  \
# 0  https://api.github.com/users/jbrockmendel/foll...
# 1  https://api.github.com/users/jbrockmendel/foll...
# 2  https://api.github.com/users/LSturtew/followin...
# 3  https://api.github.com/users/ehallam/following...
# 4  https://api.github.com/users/ianliu/following{...
#
#                                            gists_url  \
# 0  https://api.github.com/users/jbrockmendel/gist...
# 1  https://api.github.com/users/jbrockmendel/gist...
# 2  https://api.github.com/users/LSturtew/gists{/g...
# 3  https://api.github.com/users/ehallam/gists{/gi...
# 4  https://api.github.com/users/ianliu/gists{/gis...
#
#                                          starred_url  \
# 0  https://api.github.com/users/jbrockmendel/star...
# 1  https://api.github.com/users/jbrockmendel/star...
# 2  https://api.github.com/users/LSturtew/starred{...
# 3  https://api.github.com/users/ehallam/starred{/...
# 4  https://api.github.com/users/ianliu/starred{/o...
#
#                                    subscriptions_url  \
# 0  https://api.github.com/users/jbrockmendel/subs...
# 1  https://api.github.com/users/jbrockmendel/subs...
# 2  https://api.github.com/users/LSturtew/subscrip...
# 3  https://api.github.com/users/ehallam/subscript...
# 4  https://api.github.com/users/ianliu/subscriptions
#
#                                 organizations_url  \
# 0  https://api.github.com/users/jbrockmendel/orgs
# 1  https://api.github.com/users/jbrockmendel/orgs
# 2      https://api.github.com/users/LSturtew/orgs
# 3       https://api.github.com/users/ehallam/orgs
# 4        https://api.github.com/users/ianliu/orgs
#
#                                          repos_url  \
# 0  https://api.github.com/users/jbrockmendel/repos
# 1  https://api.github.com/users/jbrockmendel/repos
# 2      https://api.github.com/users/LSturtew/repos
# 3       https://api.github.com/users/ehallam/repos
# 4        https://api.github.com/users/ianliu/repos
#
#                                           events_url  \
# 0  https://api.github.com/users/jbrockmendel/even...
# 1  https://api.github.com/users/jbrockmendel/even...
# 2  https://api.github.com/users/LSturtew/events{/...
# 3  https://api.github.com/users/ehallam/events{/p...
# 4  https://api.github.com/users/ianliu/events{/pr...
#
#                                  received_events_url  type site_admin
# 0  https://api.github.com/users/jbrockmendel/rece...  User      False
# 1  https://api.github.com/users/jbrockmendel/rece...  User      False
# 2  https://api.github.com/users/LSturtew/received...  User      False
# 3  https://api.github.com/users/ehallam/received_...  User      False
# 4  https://api.github.com/users/ianliu/received_e...  User      False

# %%
len()

# %%
len(actual_data.columns)
# Out:
# 18

# %%
# Out:
#                  login         id               node_id  \
# 0         jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
# 1         jbrockmendel    8078968  MDQ6VXNlcjgwNzg5Njg=
#
# 2             https://api.github.com/users/LSturtew
# 3              https://api.github.com/users/ehallam
# 4               https://api.github.com/users/ianliu
# 5              https://api.github.com/users/raffaem
# 6   https://api.github.com/users/jorisvandenbossche
# 7           https://api.github.com/users/topper-123
# 8             https://api.github.com/users/hitvoice
# 9           https://api.github.com/users/twoertwein
# 10         https://api.github.com/users/mvashishtha
# 11        https://api.github.com/users/jbrockmendel
# 12          https://api.github.com/users/sergiykhan
# 13              https://api.github.com/users/moojen
# 14          https://api.github.com/users/rhshadrach
# 15           https://api.github.com/users/NickCrews
# 16             https://api.github.com/users/rendner
# 17        https://api.github.com/users/jbrockmendel
# 18           https://api.github.com/users/NickCrews
# 19       https://api.github.com/users/whypandasslow
# 20             https://api.github.com/users/weikhor
# 21         https://api.github.com/users/NumberPiOso
# 22       https://api.github.com/users/theinexorable
# 23         https://api.github.com/users/RagBlufThim
# 24    https://api.github.com/users/johannes-mueller
# 25            https://api.github.com/users/tritemio
# 26          https://api.github.com/users/mach881040
# 27            https://api.github.com/users/macsakow
# 28              https://api.github.com/users/Dr-Irv
# 29             https://api.github.com/users/weikhor
#
#                                  html_url  \
# 0         https://github.com/jbrockmendel
# 1         https://github.com/jbrockmendel
# 2             https://github.com/LSturtew
# 3              https://github.com/ehallam
# 4               https://github.com/ianliu
# 5              https://github.com/raffaem
# 6   https://github.com/jorisvandenbossche
# 7           https://github.com/topper-123
# 8             https://github.com/hitvoice
# 9           https://github.com/twoertwein
# 10         https://github.com/mvashishtha
# 11        https://github.com/jbrockmendel
# 12          https://github.com/sergiykhan
# 13              https://github.com/moojen
# 14          https://github.com/rhshadrach
# 15           https://github.com/NickCrews
# 16             https://github.com/rendner
# 17        https://github.com/jbrockmendel
# 18           https://github.com/NickCrews
# 19       https://github.com/whypandasslow
# 20             https://github.com/weikhor
# 21         https://github.com/NumberPiOso
# 22       https://github.com/theinexorable
# 23         https://github.com/RagBlufThim
# 24    https://github.com/johannes-mueller
# 25            https://github.com/tritemio
# 26          https://github.com/mach881040
# 27            https://github.com/macsakow
# 28              https://github.com/Dr-Irv
# 29             https://github.com/weikhor
#
#                                         followers_url  \
# 0   https://api.github.com/users/jbrockmendel/foll...
# 1   https://api.github.com/users/jbrockmendel/foll...
# 2     https://api.github.com/users/LSturtew/followers
# 3      https://api.github.com/users/ehallam/followers
# 4       https://api.github.com/users/ianliu/followers
# 5      https://api.github.com/users/raffaem/followers
# 6   https://api.github.com/users/jorisvandenbossch...
# 7   https://api.github.com/users/topper-123/followers
# 8     https://api.github.com/users/hitvoice/followers
# 9   https://api.github.com/users/twoertwein/followers
# 10  https://api.github.com/users/mvashishtha/follo...
# 11  https://api.github.com/users/jbrockmendel/foll...
# 12  https://api.github.com/users/sergiykhan/followers
# 13      https://api.github.com/users/moojen/followers
# 14  https://api.github.com/users/rhshadrach/followers
# 15   https://api.github.com/users/NickCrews/followers
# 16     https://api.github.com/users/rendner/followers
# 17  https://api.github.com/users/jbrockmendel/foll...
# 18   https://api.github.com/users/NickCrews/followers
# 19  https://api.github.com/users/whypandasslow/fol...
# 20     https://api.github.com/users/weikhor/followers
# 21  https://api.github.com/users/NumberPiOso/follo...
# 22  https://api.github.com/users/theinexorable/fol...
# 23  https://api.github.com/users/RagBlufThim/follo...
# 24  https://api.github.com/users/johannes-mueller/...
# 25    https://api.github.com/users/tritemio/followers
# 26  https://api.github.com/users/mach881040/followers
# 27    https://api.github.com/users/macsakow/followers
# 28      https://api.github.com/users/Dr-Irv/followers
# 29     https://api.github.com/users/weikhor/followers
#
#                                         following_url  \
# 0   https://api.github.com/users/jbrockmendel/foll...
# 1   https://api.github.com/users/jbrockmendel/foll...
# 2   https://api.github.com/users
# 1      https://api.github.com/users/jbrockmendel/orgs
# 2          https://api.github.com/users/LSturtew/orgs
# 3           https://api.github.com/users/ehallam/orgs
# 4            https://api.github.com/users/ianliu/orgs
# 5           https://api.github.com/users/raffaem/orgs
# 6   https://api.github.com/users/jorisvandenbossch...
# 7        https://api.github.com/users/topper-123/orgs
# 8          https://api.github.com/users/hitvoice/orgs
# 9        https://api.github.com/users/twoertwein/orgs
# 10      https://api.github.com/users/mvashishtha/orgs
# 11     https://api.github.com/users/jbrockmendel/orgs
# 12       https://api.github.com/users/sergiykhan/orgs
# 13           https://api.github.com/users/moojen/orgs
# 14       https://api.github.com/users/rhshadrach/orgs
# 15        https://api.github.com/users/NickCrews/orgs
# 16          https://api.github.com/users/rendner/orgs
# 17     https://api.github.com/users/jbrockmendel/orgs
# 18        https://api.github.com/users/NickCrews/orgs
# 19    https://api.github.com/users/whypandasslow/orgs
# 20          https://api.github.com/users/weikhor/orgs
# 21      https://api.github.com/users/NumberPiOso/orgs
# 22    https://api.github.com/users/theinexorable/orgs
# 23      https://api.github.com/users/RagBlufThim/orgs
# 24  https://api.github.com/users/johannes-mueller/...
# 25         https://api.github.com/users/tritemio/orgs
# 26       https://api.github.com/users/mach881040/orgs
# 27         https://api.github.com/users/macsakow/orgs
# 28           https://api.github.com/users/Dr-Irv/orgs
# 29          https://api.github.com/users/weikhor/orgs
#
#                                             repos_url  \
# 0     https://api.github.com/users/jbrockmendel/repos
# 1     https://api.github.com/users/jbrockmendel/repos
# 2         https://api.github.com/users/LSturtew/repos
# 3          https://api.github.com/users/ehallam/repos
# 4           https://api.github.com/users/ianliu/repos
# 5          https://api.github.com/users/raffaem/repos
# 6   https://api.github.com/users/jorisvandenbossch...
# 7       https://api.github.com/users/topper-123/repos
# 8         https://api.github.com/users/hitvoice/repos
# 9       https://api.github.com/users/twoertwein/repos
# 10     https://api.github.com/users/mvashishtha/repos
# 11    https://api.github.com/users/jbrockmendel/repos
# 12      https://api.github.com/users/sergiykhan/repos
# 13          https://api.github.com/users/moojen/repos
# 14      https://api.github.com/users/rhshadrach/repos
# 15       https://api.github.com/users/NickCrews/repos
# 16         https://api.github.com/users/rendner/repos
# 17    https://api.github.com/users/jbrockmendel/repos
# 18       https://api.github.com/users/NickCrews/repos
# 19   https://api.github.com/users/whypandasslow/repos
# 20         https://api.github.com/users/weikhor/repos
# 21     https://api.github.com/users/NumberPiOso/repos
# 22   https://api.github.com/users/theinexorable/repos
# 23     https://api.github.com/users/RagBlufThim/repos
# 24  https://api.github.com/users/johannes-mueller/...
# 25        https://api.github.com/users/tritemio/repos
# 26      https://api.github.com/users/mach881040/repos
# 27        https://api.github.com/users/macsakow/repos
# 28          https://api.github.com/users/Dr-Irv/repos
# 29         https://api.github.com/users/weikhor/repos
#
#                                            events_url  \
# 0   https://api.github.com/users/jbrockmendel/even...
# 1   https://api.github.com/users/jbrockmendel/even...
# 2   https://api.github.com/users/LSturtew/events{/...
# 3   https://api.github.com/users/ehallam/events{/p...
# 4   https://api.github.com/users/ianliu/events{/pr...
# 5   https://api.github.com/users/raffaem/events{/p...
# 6   https://api.github.com/users/jorisvandenbossch...
# 7   https://api.github.com/users/topper-123/events...
# 8   https://api.github.com/users/hitvoice/events{/...
# 9   https://api.github.com/users/twoertwein/events...
# 10  https://api.github.com/users/mvashishtha/event...
# 11  https://api.github.com/users/jbrockmendel/even...
# 12  https://api.github.com/users/sergiykhan/events...
# 13  https://api.github.com/users/moojen/events{/pr...
# 14  https://api.github.com/users/rhshadrach/events...
# 15  https://api.github.com/users/NickCrews/events{...
# 16  https://api.github.com/users/rendner/events{/p...
# 17  https://api.github.com/users/jbrockmendel/even...
# 18  https://api.github.com/users/NickCrews/events{...
# 19  https://api.github.com/users/whypandasslow/eve...
# 20  https://api.github.com/users/weikhor/events{/p...
# 21  https://api.github.com/users/NumberPiOso/event...
# 22  https://api.github.com/users/theinexorable/eve...
# 23  https://api.github.com/users/RagBlufThim/event...
# 24  https://api.github.com/users/johannes-mueller/...
# 25  https://api.github.com/users/tritemio/events{/...
# 26  https://api.github.com/users/mach881040/events...
# 27  https://api.github.com/users/macsakow/events{/...
# 28  https://api.github.com/users/Dr-Irv/events{/pr...
# 29  https://api.github.com/users/weikhor/events{/p...
#
#                                   received_events_url  type site_admin
# 0   https://api.github.com/users/jbrockmendel/rece...  User      False
# 1   https://api.github.com/users/jbrockmendel/rece...  User      False
# 2   https://api.github.com/users/LSturtew/received...  User      False
# 3   https://api.github.com/users/ehallam/received_...  User      False
# 4   https://api.github.com/users/ianliu/received_e...  User      False
# 5   https://api.github.com/users/raffaem/received_...  User      False
# 6   https://api.github.com/users/jorisvandenbossch...  User      False
# 7   https://api.github.com/users/topper-123/receiv...  User      False
# 8   https://api.github.com/users/hitvoice/received...  User      False
# 9   https://api.github.com/users/twoertwein/receiv...  User      False
# 10  https://api.github.com/users/mvashishtha/recei...  User      False
# 11  https://api.github.com/users/jbrockmendel/rece...  User      False
# 12  https://api.github.com/users/sergiykhan/receiv...  User      False
# 13  https://api.github.com/users/moojen/received_e...  User      False
# 14  https://api.github.com/users/rhshadrach/receiv...  User      False
# 15  https://api.github.com/users/NickCrews/receive...  User      False
# 16  https://api.github.com/users/rendner/received_...  User      False
# 17  https://api.github.com/users/jbrockmendel/rece...  User      False
# 18  https://api.github.com/users/NickCrews/receive...  User      False
# 19  https://api.github.com/users/whypandasslow/rec...  User      False
# 20  https://api.github.com/users/weikhor/received_...  User      False
# 21  https://api.github.com/users/NumberPiOso/recei...  User      False
# 22  https://api.github.com/users/theinexorable/rec...  User      False
# 23  https://api.github.com/users/RagBlufThim/recei...  User      False
# 24  https://api.github.com/users/johannes-mueller/...  User      False
# 25  https://api.github.com/users/tritemio/received...  User      False
# 26  https://api.github.com/users/mach881040/receiv...  User      False
# 27  https://api.github.com/users/macsakow/received...  User      False
# 28  https://api.github.com/users/Dr-Irv/received_e...  User      False
# 29  https://api.github.com/users/weikhor/received_...  User      False

# %% [markdown]
# # Joining  two table

# %% [raw]
# """
# First table has no user data
#
# while second table has only user data
#
# """

# %%
print(len(df_without_user.columns))
print(len(actual_data.columns))
print(len(result_1.columns))
# Out:
# 28
# 18
# 46

# %%
result_1 = pd.concat([actual_data, df_without_user], axis=1)
display(result_1.head(5))
# Out:
#           login        id               node_id  \
# 0  jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 1  jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 2      LSturtew  56136443  MDQ6VXNlcjU2MTM2NDQz
# 3       ehallam  20362314  MDQ6VXNlcjIwMzYyMzE0
# 4        ianliu     30196      MDQ6VXNlcjMwMTk2
#
#                                           avatar_url gravatar_id  \
# 0  https://avatars.githubusercontent.com/u/807896...
# 1  https://avatars.githubusercontent.com/u/807896...
# 2  https://avatars.githubusercontent.com/u/561364...
# 3  https://avatars.githubusercontent.com/u/203623...
# 4  https://avatars.githubusercontent.com/u/30196?v=4
#
#                                          url                         html_url  \
# 0  https://api.github.com/users/jbrockmendel  https://github.com/jbrockmendel
# 1  https://api.github.com/users/jbrockmendel  https://github.com/jbrockmendel
# 2      https://api.github.com/users/LSturtew      https://github.com/LSturtew
# 3       https://api.github.com/users/ehallam       https://github.com/ehallam
# 4        https://api.github.com/users/ianliu        https://github.com/ianliu
#
#                                        followers_url  \
# 0  https://api.github.com/users/jbrockmendel/foll...
# 1  https://api.github.com/users/jbrockmendel/foll...
# 2    https://api.github.com/users/LSturtew/followers
# 3     https://api.github.com/users/ehallam/followers
# 4      https://api.github.com/users/ianliu/followers
#
#                                        following_url  \
# 0  https://api.github.com/users/jbrockmendel/foll...
# 1  https://api.github.com/users/jbrockmendel/foll...
# 2  https://api.github.com/users/LSturtew/followin...
# 3  https://api.github.com/users/ehallam/following...
# 4  https://api.github.com/users/ianliu/following{...
#
#                                            gists_url  ...  \
# 0  https://api.github.com/users/jbrockmendel/gist...  ...
# 1  https://api.github.com/users/jbrockmendel/gist...  ...
# 2  https://api.github.com/users/LSturtew/gists{/g...  ...
# 3  https://api.github.com/users/ehallam/gists{/gi...  ...
# 4  https://api.github.com/users/ianliu/gists{/gis...  ...
#
#              updated_at closed_at author_association active_lock_reason  \
# 0  2022-03-05T02:51:25Z      None             MEMBER               None
# 1  2022-03-05T01:06:08Z      None             MEMBER               None
# 2  2022-03-04T21:26:16Z      None               NONE               None
# 3  2022-03-04T18:36:18Z      None        CONTRIBUTOR               None
# 4  2022-03-04T17:19:14Z      None               NONE               None
#
#    draft                                       pull_request  \
# 0  False  {'url': 'https://api.github.com/repos/pandas-d...
# 1  False  {'url': 'https://api.github.com/repos/pandas-d...
# 2  False  {'url': 'https://api.github.com/repos/pandas-d...
# 3   True  {'url': 'https://api.github.com/repos/pandas-d...
# 4    NaN                                                NaN
#
#                                                 body  \
# 0  - [ ] closes #xxxx (Replace xxxx with the Gith...
# 1  - [ ] closes #xxxx (Replace xxxx with the Gith...
# 2  @cvonsteg started the effort to implement this...
# 3  Moved title to the top of page and reworded ti...
# 4  ### Pandas version checks\n\n- [X] I have chec...
#
#                                            reactions  \
# 0  {'url': 'https://api.github.com/repos/pandas-d...
# 1  {'url': 'https://api.github.com/repos/pandas-d...
# 2  {'url': 'https://api.github.com/repos/pandas-d...
# 3  {'url': 'https://api.github.com/repos/pandas-d...
# 4  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                         timeline_url performed_via_github_app
# 0  https://api.github.com/repos/pandas-dev/pandas...                     None
# 1  https://api.github.com/repos/pandas-dev/pandas...                     None
# 2  https://api.github.com/repos/pandas-dev/pandas...                     None
# 3  https://api.github.com/repos/pandas-dev/pandas...                     None
# 4  https://api.github.com/repos/pandas-dev/pandas...                     None
#
# [5 rows x 46 columns]
